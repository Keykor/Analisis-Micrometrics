# %%
import pandas as pd

# %%
df = pd.read_json("raw_logs.json")

# %%
df_filtrado = df.fillna(0)
df_filtrado = df_filtrado[df_filtrado["level"] > 0]
df_filtrado
# Out:
#                         name  level  avgFocusDuration  avgPauseDuration  \
# 0      tricky_dolphin_rj96ae    2.0        510.882353       6088.000000
# 5    modern_wolverine_tonn9h    4.0        768.428571       2186.333333
# 7         brave_otter_l05i7f    4.0       2257.888889       3601.400000
# 8         rare_monkey_8k2kgc    2.0       1239.333333       2641.750000
# 9           wet_otter_j0a16e    2.0       4306.428571       2922.200000
# ..                       ...    ...               ...               ...
# 218       smooth_dodo_fhlhfp    2.0        270.607143       3356.000000
# 220        bad_shrimp_fm1rvh    1.0       1790.400000       4217.940000
# 221         tall_mule_aklxv9    2.0        327.500000       3565.500000
# 223  cowardly_dolphin_md3hlg    3.0       2298.434783       3850.214286
# 224        rude_quail_yd9pxg    2.0       4923.533333       9765.142857
#
#      avgSpeedPerTest  clicksPerTest  timePerTest  totalFocus  totalPauses  \
# 0           0.127165             14       168376        17.0         12.0
# 5           0.265398             11        42332         7.0          3.0
# 7           0.117496             21        86542         9.0          5.0
# 8           0.150432             19        54730         9.0          4.0
# 9           0.079709              9        63014         7.0          5.0
# ..               ...            ...          ...         ...          ...
# 218         0.156524             49       166891        28.0          1.0
# 220         0.062933             17       447732        10.0         50.0
# 221         0.116372             14        56237         6.0          2.0
# 223         0.126171             40       202855        23.0         14.0
# 224         0.054662             19       274390        15.0         14.0
#
#      avgIntratecla  totalBorrado
# 0         0.000000           0.0
# 5       545.971429           1.0
# 7       271.538462           0.0
# 8       176.312500           0.0
# 9       786.882353           0.0
# ..             ...           ...
# 218     211.488722          16.0
# 220       0.000000           0.0
# 221     923.600000           0.0
# 223     352.647727           7.0
# 224       0.000000           0.0
#
# [147 rows x 11 columns]

# %%
df_filtrado.describe()
# Out:
#             level  avgFocusDuration  avgPauseDuration  avgSpeedPerTest  \
# count  147.000000        147.000000        147.000000       147.000000
# mean     2.482993       1372.598308       3620.621843         0.118182
# std      1.002420       1689.672652       2416.814447         0.051618
# min      1.000000         21.416667          0.000000         0.024968
# 25%      2.000000        499.687500       2671.750000         0.083082
# 50%      3.000000        925.103448       3356.000000         0.109056
# 75%      3.000000       1512.032967       4120.169872         0.143514
# max      4.000000      14092.000000      25187.500000         0.373299
#
#        clicksPerTest   timePerTest  totalFocus  totalPauses  avgIntratecla  \
# count     147.000000     147.00000  147.000000   147.000000     147.000000
# mean       24.401361  139742.29932   15.789116     8.176871     689.436532
# std        14.769767  104933.03444   10.227033     8.381078    1346.643004
# min         4.000000   17844.00000    1.000000     0.000000       0.000000
# 25%        11.500000   66834.00000    8.000000     3.000000     258.577659
# 50%        21.000000  113116.00000   11.000000     6.000000     398.647059
# 75%        35.000000  169425.00000   23.500000    10.500000     588.109615
# max        76.000000  715502.00000   41.000000    50.000000   10199.722222
#
#        totalBorrado
# count    147.000000
# mean       3.061224
# std        5.488749
# min        0.000000
# 25%        0.000000
# 50%        1.000000
# 75%        3.500000
# max       44.000000

# %%
"""
esto era de lo volteado

df_filtrado = df_filtrado[df_filtrado["timePerTest"] < 500000]
#df_filtrado = df_filtrado[df_filtrado["timePerTest"] < 400000]
df_filtrado = df_filtrado[df_filtrado["avgFocusDuration"] < 4000]
df_filtrado = df_filtrado[df_filtrado["totalBorrado"] < 25]
df_filtrado = df_filtrado[df_filtrado["avgIntratecla"] < 2000]
df_filtrado = df_filtrado[df_filtrado["avgFocusDuration"] < 4000]
df_filtrado = df_filtrado[df_filtrado["avgIntratecla"] > 0]
#df_filtrado = df_filtrado[df_filtrado["avgIntratecla"] < 1250]
df_filtrado = df_filtrado[df_filtrado["avgPauseDuration"] < 8000]
"""

df_filtrado = df_filtrado[df_filtrado["avgPauseDuration"] < 15000]
df_filtrado = df_filtrado[df_filtrado["avgIntratecla"] > 0]

pd.plotting.scatter_matrix(df_filtrado, figsize=(50,50))
# Out:
# array([[<AxesSubplot:xlabel='level', ylabel='level'>,
#         <AxesSubplot:xlabel='avgFocusDuration', ylabel='level'>,
#         <AxesSubplot:xlabel='avgPauseDuration', ylabel='level'>,
#         <AxesSubplot:xlabel='avgSpeedPerTest', ylabel='level'>,
#         <AxesSubplot:xlabel='clicksPerTest', ylabel='level'>,
#         <AxesSubplot:xlabel='timePerTest', ylabel='level'>,
#         <AxesSubplot:xlabel='totalFocus', ylabel='level'>,
#         <AxesSubplot:xlabel='totalPauses', ylabel='level'>,
#         <AxesSubplot:xlabel='avgIntratecla', ylabel='level'>,
#         <AxesSubplot:xlabel='totalBorrado', ylabel='level'>],
#        [<AxesSubplot:xlabel='level', ylabel='avgFocusDuration'>,
#         <AxesSubplot:xlabel='avgFocusDuration', ylabel='avgFocusDuration'>,
#         <AxesSubplot:xlabel='avgPauseDuration', ylabel='avgFocusDuration'>,
#         <AxesSubplot:xlabel='avgSpeedPerTest', ylabel='avgFocusDuration'>,
#         <AxesSubplot:xlabel='clicksPerTest', ylabel='avgFocusDuration'>,
#         <AxesSubplot:xlabel='timePerTest', ylabel='avgFocusDuration'>,
#         <AxesSubplot:xlabel='totalFocus', ylabel='avgFocusDuration'>,
#         <AxesSubplot:xlabel='totalPauses', ylabel='avgFocusDuration'>,
#         <AxesSubplot:xlabel='avgIntratecla', ylabel='avgFocusDuration'>,
#         <AxesSubplot:xlabel='totalBorrado', ylabel='avgFocusDuration'>],
#        [<AxesSubplot:xlabel='level', ylabel='avgPauseDuration'>,
#         <AxesSubplot:xlabel='avgFocusDuration', ylabel='avgPauseDuration'>,
#         <AxesSubplot:xlabel='avgPauseDuration', ylabel='avgPauseDuration'>,
#         <AxesSubplot:xlabel='avgSpeedPerTest', ylabel='avgPauseDuration'>,
#         <AxesSubplot:xlabel='clicksPerTest', ylabel='avgPauseDuration'>,
#         <AxesSubplot:xlabel='timePerTest', ylabel='avgPauseDuration'>,
#         <AxesSubplot:xlabel='totalFocus', ylabel='avgPauseDuration'>,
#         <AxesSubplot:xlabel='totalPauses', ylabel='avgPauseDuration'>,
#         <AxesSubplot:xlabel='avgIntratecla', ylabel='avgPauseDuration'>,
#         <AxesSubplot:xlabel='totalBorrado', ylabel='avgPauseDuration'>],
#        [<AxesSubplot:xlabel='level', ylabel='avgSpeedPerTest'>,
#         <AxesSubplot:xlabel='avgFocusDuration', ylabel='avgSpeedPerTest'>,
#         <AxesSubplot:xlabel='avgPauseDuration', ylabel='avgSpeedPerTest'>,
#         <AxesSubplot:xlabel='avgSpeedPerTest', ylabel='avgSpeedPerTest'>,
#         <AxesSubplot:xlabel='clicksPerTest', ylabel='avgSpeedPerTest'>,
#         <AxesSubplot:xlabel='timePerTest', ylabel='avgSpeedPerTest'>,
#         <AxesSubplot:xlabel='totalFocus', ylabel='avgSpeedPerTest'>,
#         <AxesSubplot:xlabel='totalPauses', ylabel='avgSpeedPerTest'>,
#         <AxesSubplot:xlabel='avgIntratecla', ylabel='avgSpeedPerTest'>,
#         <AxesSubplot:xlabel='totalBorrado', ylabel='avgSpeedPerTest'>],
#        [<AxesSubplot:xlabel='level', ylabel='clicksPerTest'>,
#         <AxesSubplot:xlabel='avgFocusDuration', ylabel='clicksPerTest'>,
#         <AxesSubplot:xlabel='avgPauseDuration', ylabel='clicksPerTest'>,
#         <AxesSubplot:xlabel='avgSpeedPerTest', ylabel='clicksPerTest'>,
#         <AxesSubplot:xlabel='clicksPerTest', ylabel='clicksPerTest'>,
#         <AxesSubplot:xlabel='timePerTest', ylabel='clicksPerTest'>,
#         <AxesSubplot:xlabel='totalFocus', ylabel='clicksPerTest'>,
#         <AxesSubplot:xlabel='totalPauses', ylabel='clicksPerTest'>,
#         <AxesSubplot:xlabel='avgIntratecla', ylabel='clicksPerTest'>,
#         <AxesSubplot:xlabel='totalBorrado', ylabel='clicksPerTest'>],
#        [<AxesSubplot:xlabel='level', ylabel='timePerTest'>,
#         <AxesSubplot:xlabel='avgFocusDuration', ylabel='timePerTest'>,
#         <AxesSubplot:xlabel='avgPauseDuration', ylabel='timePerTest'>,
#         <AxesSubplot:xlabel='avgSpeedPerTest', ylabel='timePerTest'>,
#         <AxesSubplot:xlabel='clicksPerTest', ylabel='timePerTest'>,
#         <AxesSubplot:xlabel='timePerTest', ylabel='timePerTest'>,
#         <AxesSubplot:xlabel='totalFocus', ylabel='timePerTest'>,
#         <AxesSubplot:xlabel='totalPauses', ylabel='timePerTest'>,
#         <AxesSubplot:xlabel='avgIntratecla', ylabel='timePerTest'>,
#         <AxesSubplot:xlabel='totalBorrado', ylabel='timePerTest'>],
#        [<AxesSubplot:xlabel='level', ylabel='totalFocus'>,
#         <AxesSubplot:xlabel='avgFocusDuration', ylabel='totalFocus'>,
#         <AxesSubplot:xlabel='avgPauseDuration', ylabel='totalFocus'>,
#         <AxesSubplot:xlabel='avgSpeedPerTest', ylabel='totalFocus'>,
#         <AxesSubplot:xlabel='clicksPerTest', ylabel='totalFocus'>,
#         <AxesSubplot:xlabel='timePerTest', ylabel='totalFocus'>,
#         <AxesSubplot:xlabel='totalFocus', ylabel='totalFocus'>,
#         <AxesSubplot:xlabel='totalPauses', ylabel='totalFocus'>,
#         <AxesSubplot:xlabel='avgIntratecla', ylabel='totalFocus'>,
#         <AxesSubplot:xlabel='totalBorrado', ylabel='totalFocus'>],
#        [<AxesSubplot:xlabel='level', ylabel='totalPauses'>,
#         <AxesSubplot:xlabel='avgFocusDuration', ylabel='totalPauses'>,
#         <AxesSubplot:xlabel='avgPauseDuration', ylabel='totalPauses'>,
#         <AxesSubplot:xlabel='avgSpeedPerTest', ylabel='totalPauses'>,
#         <AxesSubplot:xlabel='clicksPerTest', ylabel='totalPauses'>,
#         <AxesSubplot:xlabel='timePerTest', ylabel='totalPauses'>,
#         <AxesSubplot:xlabel='totalFocus', ylabel='totalPauses'>,
#         <AxesSubplot:xlabel='totalPauses', ylabel='totalPauses'>,
#         <AxesSubplot:xlabel='avgIntratecla', ylabel='totalPauses'>,
#         <AxesSubplot:xlabel='totalBorrado', ylabel='totalPauses'>],
#        [<AxesSubplot:xlabel='level', ylabel='avgIntratecla'>,
#         <AxesSubplot:xlabel='avgFocusDuration', ylabel='avgIntratecla'>,
#         <AxesSubplot:xlabel='avgPauseDuration', ylabel='avgIntratecla'>,
#         <AxesSubplot:xlabel='avgSpeedPerTest', ylabel='avgIntratecla'>,
#         <AxesSubplot:xlabel='clicksPerTest', ylabel='avgIntratecla'>,
#         <AxesSubplot:xlabel='timePerTest', ylabel='avgIntratecla'>,
#         <AxesSubplot:xlabel='totalFocus', ylabel='avgIntratecla'>,
#         <AxesSubplot:xlabel='totalPauses', ylabel='avgIntratecla'>,
#         <AxesSubplot:xlabel='avgIntratecla', ylabel='avgIntratecla'>,
#         <AxesSubplot:xlabel='totalBorrado', ylabel='avgIntratecla'>],
#        [<AxesSubplot:xlabel='level', ylabel='totalBorrado'>,
#         <AxesSubplot:xlabel='avgFocusDuration', ylabel='totalBorrado'>,
#         <AxesSubplot:xlabel='avgPauseDuration', ylabel='totalBorrado'>,
#         <AxesSubplot:xlabel='avgSpeedPerTest', ylabel='totalBorrado'>,
#         <AxesSubplot:xlabel='clicksPerTest', ylabel='totalBorrado'>,
#         <AxesSubplot:xlabel='timePerTest', ylabel='totalBorrado'>,
#         <AxesSubplot:xlabel='totalFocus', ylabel='totalBorrado'>,
#         <AxesSubplot:xlabel='totalPauses', ylabel='totalBorrado'>,
#         <AxesSubplot:xlabel='avgIntratecla', ylabel='totalBorrado'>,
#         <AxesSubplot:xlabel='totalBorrado', ylabel='totalBorrado'>]],
#       dtype=object)

# %%
df_a = df_filtrado[df_filtrado["avgSpeedPerTest"] > 0.30]
df_a
# Out:
#                name  level  avgFocusDuration  avgPauseDuration  \
# 200  bad_pug_a7y0ls    1.0             849.0               0.0
#
#      avgSpeedPerTest  clicksPerTest  timePerTest  totalFocus  totalPauses  \
# 200         0.373299             40        52371        10.0          0.0
#
#      avgIntratecla  totalBorrado
# 200          266.5           1.0

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn import metrics
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.preprocessing import StandardScaler

def evaluate(model, x, y):
    y_pred = model.predict(x)
    return {
        'MAE': metrics.mean_absolute_error(y_pred,y),
        'MSE': metrics.mean_squared_error(y_pred,y),
        'R^2': metrics.r2_score(y,y_pred)
    }

# %%
feature_cols = ['avgFocusDuration', 'avgPauseDuration', 'avgSpeedPerTest', 'clicksPerTest',	'timePerTest', 'totalFocus', 'totalPauses', 'avgIntratecla', 'totalBorrado']
#feature_cols = ['timePerTest', 'totalFocus', 'avgIntratecla']
#feature_cols = ['avgFocusDuration', 'avgPauseDuration', 'avgSpeedPerTest', 'clicksPerTest',	'totalFocus', 'totalPauses', 'avgIntratecla', 'totalBorrado']
X_df = df_filtrado.loc[:, feature_cols]
X_df.shape
# Out:
# (130, 9)

# %%
y = df_filtrado['level']
y.shape
# Out:
# (130,)

# %%
X = X_df.to_numpy()
y = y.to_numpy()

# %% [markdown]
# ### Entrenamiento "normal" ###

# %%
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3)
fold_number = 1
list_r2 = []
list_mae = []
list_mse = []
for train, test in cv.split(X, y):
    x_train = X[train]
    y_train = y[train]
    x_test = X[test]
    y_test = y[test]

    sd = StandardScaler()
    sd.fit(x_train)
    x_train = sd.transform(x_train)
    x_test = sd.transform(x_test)

    model = LinearRegression()
    #model = DecisionTreeClassifier()
    model.fit(x_train, y_train)

    print("------------------------------------------")
    print("FOLD NUMBER " + str(fold_number))
    fold_number += 1

    training_result = evaluate(model, x_train, y_train)
    print("Training evaluate results")
    print(training_result)

    testing_result = evaluate(model, x_test, y_test)
    print("Testing evaluate results")
    print(testing_result)
    list_r2.append(testing_result['R^2'])
    list_mae.append(testing_result['MAE'])
    list_mse.append(testing_result['MSE'])

    print("------------------------------------------")
    print("")

print('R^2: %.3f (%.3f)' % (np.mean(list_r2), np.std(list_r2)))
print('MAE: %.3f (%.3f)' % (np.mean(list_mae), np.std(list_mae)))
print('MSE: %.3f (%.3f)' % (np.mean(list_mse), np.std(list_mse)))
# Out:
# ------------------------------------------
# FOLD NUMBER 1
# Training evaluate results
# {'MAE': 0.7540064014657049, 'MSE': 0.8315246153921204, 'R^2': 0.17023323661592515}
# Testing evaluate results
# {'MAE': 0.9582834727372926, 'MSE': 1.4251554944479439, 'R^2': -0.4509113166367622}
# ------------------------------------------
#
# ------------------------------------------
# FOLD NUMBER 2
# Training evaluate results
# {'MAE': 0.8011280545988483, 'MSE': 0.8925205950410892, 'R^2': 0.10936620312600431}
# Testing evaluate results
# {'MAE': 0.698784072954867, 'MSE': 0.7300863951007573, 'R^2': 0.2567192724576629}
# ------------------------------------------
#
# ------------------------------------------
# FOLD NUMBER 3
# Training evaluate results
# {'MAE': 0.7757949480683266, 'MSE': 0.8744227985737052, 'R^2': 0.12742574065640389}
# Testing evaluate results
# {'MAE': 0.864974542522513, 'MSE': 0.9484925951542794, 'R^2': 0.03436597240317363}
# ------------------------------------------
#
# ------------------------------------------
# FOLD NUMBER 4
# Training evaluate results
# {'MAE': 0.7867920201985583, 'MSE': 0.8690932579837163, 'R^2': 0.13274401454008633}
# Testing evaluate results
# {'MAE': 0.8370284432137057, 'MSE': 0.9596531516841849, 'R^2': 0.02300371906851073}
# ------------------------------------------
#
# ------------------------------------------
# FOLD NUMBER 5
# Training evaluate results
# {'MAE': 0.7989321357549054, 'MSE': 0.8979920799755582, 'R^2': 0.11855631845795078}
# Testing evaluate results
# {'MAE': 0.6746653482496398, 'MSE': 0.6887502088269238, 'R^2': 0.20274804594691698}
# ------------------------------------------
#
# ------------------------------------------
# FOLD NUMBER 6
# Training evaluate results
# {'MAE': 0.7723651131985292, 'MSE': 0.8651303461498606, 'R^2': 0.1354380706347319}
# Testing evaluate results
# {'MAE': 0.8875968347417748, 'MSE': 1.0113807747520331, 'R^2': -0.005431476077021324}
# ------------------------------------------
#
# ------------------------------------------
# FOLD NUMBER 7
# Training evaluate results
# {'MAE': 0.7860155135934509, 'MSE': 0.879647007343396, 'R^2': 0.12093094732634346}
# Testing evaluate results
# {'MAE': 0.8414013597557927, 'MSE': 0.9031906917531098, 'R^2': 0.10212219466896721}
# ------------------------------------------
#
# ------------------------------------------
# FOLD NUMBER 8
# Training evaluate results
# {'MAE': 0.7651824897327192, 'MSE': 0.8399228666141905, 'R^2': 0.16062898809449144}
# Testing evaluate results
# {'MAE': 0.9267156493584303, 'MSE': 1.2985086297452593, 'R^2': -0.2908703436879345}
# ------------------------------------------
#
# ------------------------------------------
# FOLD NUMBER 9
# Training evaluate results
# {'MAE': 0.7942699278502188, 'MSE': 0.8728245845867001, 'R^2': 0.1277488875450914}
# Testing evaluate results
# {'MAE': 0.7864714684452139, 'MSE': 0.9624255751800177, 'R^2': 0.043235751732805916}
# ------------------------------------------
#
# ------------------------------------------
# FOLD NUMBER 10
# Training evaluate results
# {'MAE': 0.7558438079257734, 'MSE': 0.8476098895993596, 'R^2': 0.15294701571575164}
# Testing evaluate results
# {'MAE': 0.9520881788064386, 'MSE': 1.214968760800639, 'R^2': -0.20782188573710614}
# ------------------------------------------
#
# ------------------------------------------
# FOLD NUMBER 11
# Training evaluate results
# {'MAE': 0.7581549904782118, 'MSE': 0.8285577183413141, 'R^2': 0.1731938616143569}
# Testing evaluate results
# {'MAE': 0.9591166638176024, 'MSE': 1.386796449794144, 'R^2': -0.41185903623620645}
# ------------------------------------------
#
# ------------------------------------------
# FOLD NUMBER 12
# Training evaluate results
# {'MAE': 0.7635575713831233, 'MSE': 0.8447761973015645, 'R^2': 0.15700966869360555}
# Testing evaluate results
# {'MAE': 0.9823139607910795, 'MSE': 1.2178324477590707, 'R^2': -0.2398414678992946}
# ------------------------------------------
#
# ------------------------------------------
# FOLD NUMBER 13
# Training evaluate results
# {'MAE': 0.8045823062389882, 'MSE': 0.9072557546531765, 'R^2': 0.09466219380031093}
# Testing evaluate results
# {'MAE': 0.6829975291465877, 'MSE': 0.6284546452637562, 'R^2': 0.3601877406652122}
# ------------------------------------------
#
# ------------------------------------------
# FOLD NUMBER 14
# Training evaluate results
# {'MAE': 0.7755684827746102, 'MSE': 0.8568886411477248, 'R^2': 0.14492283068441414}
# Testing evaluate results
# {'MAE': 0.9384537034652936, 'MSE': 1.1377483089838831, 'R^2': -0.15831002541130235}
# ------------------------------------------
#
# ------------------------------------------
# FOLD NUMBER 15
# Training evaluate results
# {'MAE': 0.7769959537800942, 'MSE': 0.8671051889838063, 'R^2': 0.14887401893020757}
# Testing evaluate results
# {'MAE': 0.8193294782043525, 'MSE': 1.0099077209006408, 'R^2': -0.16900277282334453}
# ------------------------------------------
#
# ------------------------------------------
# FOLD NUMBER 16
# Training evaluate results
# {'MAE': 0.8093382399249828, 'MSE': 0.9109916877321983, 'R^2': 0.08960686133989904}
# Testing evaluate results
# {'MAE': 0.7434515530641228, 'MSE': 0.7656327781235982, 'R^2': 0.23887094410065812}
# ------------------------------------------
#
# ------------------------------------------
# FOLD NUMBER 17
# Training evaluate results
# {'MAE': 0.78108135117903, 'MSE': 0.8577988369425443, 'R^2': 0.1427647628189158}
# Testing evaluate results
# {'MAE': 0.809411203902203, 'MSE': 1.0590206233227315, 'R^2': -0.05279109024436246}
# ------------------------------------------
#
# ------------------------------------------
# FOLD NUMBER 18
# Training evaluate results
# {'MAE': 0.7663735445109013, 'MSE': 0.8549594391281631, 'R^2': 0.14560229506311684}
# Testing evaluate results
# {'MAE': 0.8939162282354681, 'MSE': 1.0989494386318133, 'R^2': -0.09248503016927323}
# ------------------------------------------
#
# ------------------------------------------
# FOLD NUMBER 19
# Training evaluate results
# {'MAE': 0.7881132655076906, 'MSE': 0.8784079061254372, 'R^2': 0.12216923441735217}
# Testing evaluate results
# {'MAE': 0.751239850499885, 'MSE': 0.8518156825081813, 'R^2': 0.15319499797716085}
# ------------------------------------------
#
# ------------------------------------------
# FOLD NUMBER 20
# Training evaluate results
# {'MAE': 0.777153559547404, 'MSE': 0.8620322784588572, 'R^2': 0.13853410280162837}
# Testing evaluate results
# {'MAE': 0.8711221901486089, 'MSE': 1.0394059151323956, 'R^2': -0.03329176269044032}
# ------------------------------------------
#
# ------------------------------------------
# FOLD NUMBER 21
# Training evaluate results
# {'MAE': 0.7805760622027323, 'MSE': 0.8676271393013812, 'R^2': 0.1342070338317095}
# Testing evaluate results
# {'MAE': 0.8622546376766541, 'MSE': 0.9655227559888687, 'R^2': 0.017028037577597854}
# ------------------------------------------
#
# ------------------------------------------
# FOLD NUMBER 22
# Training evaluate results
# {'MAE': 0.7795888243563559, 'MSE': 0.8608813794034399, 'R^2': 0.14093853312044813}
# Testing evaluate results
# {'MAE': 0.8183993523027792, 'MSE': 1.079114847864462, 'R^2': -0.09861692342827744}
# ------------------------------------------
#
# ------------------------------------------
# FOLD NUMBER 23
# Training evaluate results
# {'MAE': 0.7938313883140854, 'MSE': 0.8842657165037678, 'R^2': 0.11760363076103819}
# Testing evaluate results
# {'MAE': 0.7710781402302607, 'MSE': 0.8016232850542099, 'R^2': 0.18388954714360584}
# ------------------------------------------
#
# ------------------------------------------
# FOLD NUMBER 24
# Training evaluate results
# {'MAE': 0.7753238014286024, 'MSE': 0.8592462659057386, 'R^2': 0.14257018997057458}
# Testing evaluate results
# {'MAE': 0.9160396473455273, 'MSE': 1.0705570341664017, 'R^2': -0.08990445044651696}
# ------------------------------------------
#
# ------------------------------------------
# FOLD NUMBER 25
# Training evaluate results
# {'MAE': 0.8018974705886102, 'MSE': 0.90819868667562, 'R^2': 0.10853780138372549}
# Testing evaluate results
# {'MAE': 0.6672163101322829, 'MSE': 0.5981511043457602, 'R^2': 0.30761961209292144}
# ------------------------------------------
#
# ------------------------------------------
# FOLD NUMBER 26
# Training evaluate results
# {'MAE': 0.7702381348643321, 'MSE': 0.8438630557633755, 'R^2': 0.15669138776866343}
# Testing evaluate results
# {'MAE': 0.8635578350617622, 'MSE': 1.187257016646965, 'R^2': -0.18027315184315906}
# ------------------------------------------
#
# ------------------------------------------
# FOLD NUMBER 27
# Training evaluate results
# {'MAE': 0.7700358074976117, 'MSE': 0.8485061396488539, 'R^2': 0.15205135452962748}
# Testing evaluate results
# {'MAE': 0.8833378098730267, 'MSE': 1.2113122722323004, 'R^2': -0.20418690592505162}
# ------------------------------------------
#
# ------------------------------------------
# FOLD NUMBER 28
# Training evaluate results
# {'MAE': 0.7709839661067215, 'MSE': 0.8661911502320038, 'R^2': 0.13437796353293174}
# Testing evaluate results
# {'MAE': 0.8951711668222709, 'MSE': 0.9798951932820159, 'R^2': 0.02586889609023102}
# ------------------------------------------
#
# ------------------------------------------
# FOLD NUMBER 29
# Training evaluate results
# {'MAE': 0.7588756639004913, 'MSE': 0.8444322620803282, 'R^2': 0.15612255543746445}
# Testing evaluate results
# {'MAE': 0.9657559415531284, 'MSE': 1.287467266577664, 'R^2': -0.2798939297154426}
# ------------------------------------------
#
# ------------------------------------------
# FOLD NUMBER 30
# Training evaluate results
# {'MAE': 0.7942993294894034, 'MSE': 0.8980707257955872, 'R^2': 0.10251933381400247}
# Testing evaluate results
# {'MAE': 0.754881586080759, 'MSE': 0.7184396348719326, 'R^2': 0.28578648062731415}
# ------------------------------------------
#
# R^2: -0.024 (0.210)
# MAE: 0.843 (0.091)
# MSE: 1.008 (0.216)

# %% [markdown]
# ### Entrenamiento con SelectFromModel ###

# %%
from sklearn.feature_selection import SelectFromModel

cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3)
fold_number = 1
list_r2 = []
list_mae = []
list_mse = []
for train, test in cv.split(X, y):
    x_train = X[train]
    y_train = y[train]
    x_test = X[test]
    y_test = y[test]

    sd = StandardScaler()
    sd.fit(x_train)
    x_train = sd.transform(x_train)
    x_test = sd.transform(x_test)

    model = SelectFromModel(LinearRegression())
    model.fit(x_train, y_train)

    print("------------------------------------------")
    print("FOLD NUMBER " + str(fold_number))
    fold_number += 1

    training_result = evaluate(model.estimator_, x_train, y_train)
    print("Training evaluate results")
    print(training_result)

    testing_result = evaluate(model.estimator_, x_test, y_test)
    print("Testing evaluate results")
    print(testing_result)
    list_r2.append(testing_result['R^2'])
    list_mae.append(testing_result['MAE'])
    list_mse.append(testing_result['MSE'])

    print("Columns")
    column_names = X_df.columns[model.get_support()]
    print(column_names)

    print("------------------------------------------")
    print("")

print('R^2: %.3f (%.3f)' % (np.mean(list_r2), np.std(list_r2)))
print('MAE: %.3f (%.3f)' % (np.mean(list_mae), np.std(list_mae)))
print('MSE: %.3f (%.3f)' % (np.mean(list_mse), np.std(list_mse)))
# Out:
# ------------------------------------------
# FOLD NUMBER 1
# Training evaluate results
# {'MAE': 0.7797278495249282, 'MSE': 0.858334631694605, 'R^2': 0.14347989697715036}
# Testing evaluate results
# {'MAE': 0.8222303144079819, 'MSE': 1.0527080367894777, 'R^2': -0.07173288082784146}
# Columns
# Index(['clicksPerTest', 'timePerTest', 'totalFocus', 'totalBorrado'], dtype='object')
# ------------------------------------------
#
# ------------------------------------------
# FOLD NUMBER 2
# Training evaluate results
# {'MAE': 0.7861761015930069, 'MSE': 0.8685151047185827, 'R^2': 0.1333209455829799}
# Testing evaluate results
# {'MAE': 0.8134057822739114, 'MSE': 0.9667437780993637, 'R^2': 0.01578494880245518}
# Columns
# Index(['timePerTest', 'totalFocus', 'totalBorrado'], dtype='object')
# ------------------------------------------
#
# ------------------------------------------
# FOLD NUMBER 3
# Training evaluate results
# {'MAE': 0.7785121472586519, 'MSE': 0.8646907774182316, 'R^2': 0.1371371882141582}
# Testing evaluate results
# {'MAE': 0.9245356663448768, 'MSE': 1.1228168814832151, 'R^2': -0.14310875283532143}
# Columns
# Index(['avgFocusDuration', 'timePerTest', 'totalFocus', 'totalBorrado'], dtype='object')
# ------------------------------------------
#
# ------------------------------------------
# FOLD NUMBER 4
# Training evaluate results
# {'MAE': 0.7838617640550195, 'MSE': 0.8685332414411966, 'R^2': 0.13330284720159324}
# Testing evaluate results
# {'MAE': 0.8893567737609632, 'MSE': 1.0734554664985756, 'R^2': -0.09285526408589906}
# Columns
# Index(['timePerTest', 'totalFocus'], dtype='object')
# ------------------------------------------
#
# ------------------------------------------
# FOLD NUMBER 5
# Training evaluate results
# {'MAE': 0.7872300662417144, 'MSE': 0.8777871269410017, 'R^2': 0.13838893010932363}
# Testing evaluate results
# {'MAE': 0.7372447545398015, 'MSE': 0.8832118062227898, 'R^2': -0.022347912682544324}
# Columns
# Index(['timePerTest', 'totalFocus', 'totalPauses', 'totalBorrado'], dtype='object')
# ------------------------------------------
#
# ------------------------------------------
# FOLD NUMBER 6
# Training evaluate results
# {'MAE': 0.7894904290101519, 'MSE': 0.8886948911018543, 'R^2': 0.11188900830097204}
# Testing evaluate results
# {'MAE': 0.7375675259802309, 'MSE': 0.775481483588767, 'R^2': 0.22908017219704924}
# Columns
# Index(['timePerTest', 'totalFocus'], dtype='object')
# ------------------------------------------
#
# ------------------------------------------
# FOLD NUMBER 7
# Training evaluate results
# {'MAE': 0.7836781319760333, 'MSE': 0.8777919852234767, 'R^2': 0.12278475064066485}
# Testing evaluate results
# {'MAE': 0.8015508358416853, 'MSE': 0.882893180008442, 'R^2': 0.1223003092857251}
# Columns
# Index(['timePerTest', 'totalFocus'], dtype='object')
# ------------------------------------------
#
# ------------------------------------------
# FOLD NUMBER 8
# Training evaluate results
# {'MAE': 0.7922864504908331, 'MSE': 0.8860648776825732, 'R^2': 0.11451729372194874}
# Testing evaluate results
# {'MAE': 0.8488109554834301, 'MSE': 0.9187468304072031, 'R^2': 0.0866575627128392}
# Columns
# Index(['clicksPerTest', 'timePerTest', 'totalFocus', 'totalPauses'], dtype='object')
# ------------------------------------------
#
# ------------------------------------------
# FOLD NUMBER 9
# Training evaluate results
# {'MAE': 0.7387297696363048, 'MSE': 0.8226370267797651, 'R^2': 0.177903470609709}
# Testing evaluate results
# {'MAE': 1.063943209442272, 'MSE': 1.5083053072971362, 'R^2': -0.49943292313656484}
# Columns
# Index(['timePerTest', 'totalFocus', 'totalBorrado'], dtype='object')
# ------------------------------------------
#
# ------------------------------------------
# FOLD NUMBER 10
# Training evaluate results
# {'MAE': 0.7568975812690802, 'MSE': 0.8420203607764675, 'R^2': 0.15853287204927247}
# Testing evaluate results
# {'MAE': 0.9812969976050319, 'MSE': 1.2990421013189568, 'R^2': -0.2914006771935511}
# Columns
# Index(['timePerTest', 'totalFocus'], dtype='object')
# ------------------------------------------
#
# ------------------------------------------
# FOLD NUMBER 11
# Training evaluate results
# {'MAE': 0.7775032599056662, 'MSE': 0.8490566070109817, 'R^2': 0.15273830781649433}
# Testing evaluate results
# {'MAE': 0.8687107541245584, 'MSE': 1.1690448601526764, 'R^2': -0.19017217690242338}
# Columns
# Index(['timePerTest', 'totalFocus'], dtype='object')
# ------------------------------------------
#
# ------------------------------------------
# FOLD NUMBER 12
# Training evaluate results
# {'MAE': 0.7643586899096166, 'MSE': 0.8332015459985506, 'R^2': 0.16855985105888904}
# Testing evaluate results
# {'MAE': 0.9174134587680179, 'MSE': 1.3720597889655535, 'R^2': -0.3968560502119187}
# Columns
# Index(['clicksPerTest', 'timePerTest', 'totalFocus'], dtype='object')
# ------------------------------------------
#
# ------------------------------------------
# FOLD NUMBER 13
# Training evaluate results
# {'MAE': 0.7817981181206061, 'MSE': 0.8668723881752509, 'R^2': 0.13496018940581633}
# Testing evaluate results
# {'MAE': 0.8545427681776112, 'MSE': 0.9934742008633785, 'R^2': -0.011428553891029702}
# Columns
# Index(['timePerTest', 'totalFocus'], dtype='object')
# ------------------------------------------
#
# ------------------------------------------
# FOLD NUMBER 14
# Training evaluate results
# {'MAE': 0.7773585230882983, 'MSE': 0.8776451328523869, 'R^2': 0.12421021842715219}
# Testing evaluate results
# {'MAE': 0.8535785340940831, 'MSE': 0.9171556961056333, 'R^2': 0.06626920095269873}
# Columns
# Index(['timePerTest', 'totalFocus'], dtype='object')
# ------------------------------------------
#
# ------------------------------------------
# FOLD NUMBER 15
# Training evaluate results
# {'MAE': 0.7933992807705454, 'MSE': 0.891261888754545, 'R^2': 0.1251624842133251}
# Testing evaluate results
# {'MAE': 0.7192405116169387, 'MSE': 0.7351653491357569, 'R^2': 0.14902093147984308}
# Columns
# Index(['avgPauseDuration', 'timePerTest', 'totalFocus', 'totalBorrado'], dtype='object')
# ------------------------------------------
#
# ------------------------------------------
# FOLD NUMBER 16
# Training evaluate results
# {'MAE': 0.7850100241675244, 'MSE': 0.8727632474968711, 'R^2': 0.12781018433459845}
# Testing evaluate results
# {'MAE': 0.8717448214591303, 'MSE': 0.9729901820511384, 'R^2': 0.03273328960798594}
# Columns
# Index(['avgPauseDuration', 'clicksPerTest', 'totalFocus', 'totalPauses'], dtype='object')
# ------------------------------------------
#
# ------------------------------------------
# FOLD NUMBER 17
# Training evaluate results
# {'MAE': 0.7697567918792282, 'MSE': 0.8505625936908121, 'R^2': 0.14999625164012798}
# Testing evaluate results
# {'MAE': 0.9484882033264175, 'MSE': 1.2174622295711865, 'R^2': -0.21030068704429716}
# Columns
# Index(['avgSpeedPerTest', 'timePerTest', 'totalFocus', 'totalPauses',
#        'totalBorrado'],
#       dtype='object')
# ------------------------------------------
#
# ------------------------------------------
# FOLD NUMBER 18
# Training evaluate results
# {'MAE': 0.781763766401285, 'MSE': 0.8819556021872897, 'R^2': 0.11862386929903557}
# Testing evaluate results
# {'MAE': 0.7663890483228551, 'MSE': 0.8256181245636728, 'R^2': 0.179238452639643}
# Columns
# Index(['timePerTest', 'totalFocus'], dtype='object')
# ------------------------------------------
#
# ------------------------------------------
# FOLD NUMBER 19
# Training evaluate results
# {'MAE': 0.789775225780767, 'MSE': 0.8899404347988944, 'R^2': 0.11064428296378548}
# Testing evaluate results
# {'MAE': 0.7846175005679477, 'MSE': 0.7740043792201968, 'R^2': 0.23054858771639242}
# Columns
# Index(['clicksPerTest', 'totalFocus', 'totalPauses', 'totalBorrado'], dtype='object')
# ------------------------------------------
#
# ------------------------------------------
# FOLD NUMBER 20
# Training evaluate results
# {'MAE': 0.7717694173918267, 'MSE': 0.8570750131230077, 'R^2': 0.14348811106432657}
# Testing evaluate results
# {'MAE': 0.9149888869542248, 'MSE': 1.1673419294289034, 'R^2': -0.1604752121969688}
# Columns
# Index(['avgPauseDuration', 'timePerTest', 'totalFocus', 'totalBorrado'], dtype='object')
# ------------------------------------------
#
# ------------------------------------------
# FOLD NUMBER 21
# Training evaluate results
# {'MAE': 0.7623755003179826, 'MSE': 0.8346683708446829, 'R^2': 0.1670961270963065}
# Testing evaluate results
# {'MAE': 1.0214366774032728, 'MSE': 1.348361848681619, 'R^2': -0.37272983389875636}
# Columns
# Index(['clicksPerTest', 'totalFocus', 'totalPauses'], dtype='object')
# ------------------------------------------
#
# ------------------------------------------
# FOLD NUMBER 22
# Training evaluate results
# {'MAE': 0.7667342880624062, 'MSE': 0.8423404486432036, 'R^2': 0.15944026815302392}
# Testing evaluate results
# {'MAE': 0.9203469310994722, 'MSE': 1.2556482550113435, 'R^2': -0.2783406933549215}
# Columns
# Index(['timePerTest', 'totalFocus'], dtype='object')
# ------------------------------------------
#
# ------------------------------------------
# FOLD NUMBER 23
# Training evaluate results
# {'MAE': 0.792333529860275, 'MSE': 0.8853499121169748, 'R^2': 0.11652172714905451}
# Testing evaluate results
# {'MAE': 0.7866882595122694, 'MSE': 0.8046180431405268, 'R^2': 0.18084066692319878}
# Columns
# Index(['timePerTest', 'totalFocus', 'totalBorrado'], dtype='object')
# ------------------------------------------
#
# ------------------------------------------
# FOLD NUMBER 24
# Training evaluate results
# {'MAE': 0.7893650522193891, 'MSE': 0.8828056819367409, 'R^2': 0.11906057879923826}
# Testing evaluate results
# {'MAE': 0.7924933474043807, 'MSE': 0.8683139360183858, 'R^2': 0.1159936434511617}
# Columns
# Index(['avgFocusDuration', 'timePerTest', 'totalFocus'], dtype='object')
# ------------------------------------------
#
# ------------------------------------------
# FOLD NUMBER 25
# Training evaluate results
# {'MAE': 0.7864117879321944, 'MSE': 0.8801442549785733, 'R^2': 0.13607523975321312}
# Testing evaluate results
# {'MAE': 0.7762429905678296, 'MSE': 0.8550259739938935, 'R^2': 0.010278153390630318}
# Columns
# Index(['timePerTest', 'totalFocus', 'totalBorrado'], dtype='object')
# ------------------------------------------
#
# ------------------------------------------
# FOLD NUMBER 26
# Training evaluate results
# {'MAE': 0.7874121446338488, 'MSE': 0.8612427308687453, 'R^2': 0.13932313163511068}
# Testing evaluate results
# {'MAE': 0.9519584482647988, 'MSE': 1.2621932782874565, 'R^2': -0.25476861194458933}
# Columns
# Index(['totalFocus', 'totalPauses', 'totalBorrado'], dtype='object')
# ------------------------------------------
#
# ------------------------------------------
# FOLD NUMBER 27
# Training evaluate results
# {'MAE': 0.777427334740551, 'MSE': 0.8646991779880067, 'R^2': 0.13586895550607203}
# Testing evaluate results
# {'MAE': 0.8336505074355577, 'MSE': 0.989560127268354, 'R^2': 0.016260814656753886}
# Columns
# Index(['clicksPerTest', 'timePerTest', 'totalFocus'], dtype='object')
# ------------------------------------------
#
# ------------------------------------------
# FOLD NUMBER 28
# Training evaluate results
# {'MAE': 0.7617303978013805, 'MSE': 0.8395840182656179, 'R^2': 0.16096761380945812}
# Testing evaluate results
# {'MAE': 0.8693623610283089, 'MSE': 1.2818170334410888, 'R^2': -0.27427693324437663}
# Columns
# Index(['timePerTest', 'totalFocus', 'avgIntratecla', 'totalBorrado'], dtype='object')
# ------------------------------------------
#
# ------------------------------------------
# FOLD NUMBER 29
# Training evaluate results
# {'MAE': 0.7810144499394333, 'MSE': 0.8791225857289771, 'R^2': 0.12145502437991196}
# Testing evaluate results
# {'MAE': 0.8407941266503521, 'MSE': 0.9598051248792143, 'R^2': 0.04584078762007515}
# Columns
# Index(['timePerTest', 'totalFocus', 'totalBorrado'], dtype='object')
# ------------------------------------------
#
# ------------------------------------------
# FOLD NUMBER 30
# Training evaluate results
# {'MAE': 0.7916892824279218, 'MSE': 0.8955504478273855, 'R^2': 0.1050379558834077}
# Testing evaluate results
# {'MAE': 0.7742881497170285, 'MSE': 0.7443835899518724, 'R^2': 0.2599951370478446}
# Columns
# Index(['timePerTest', 'totalFocus', 'totalBorrado'], dtype='object')
# ------------------------------------------
#
# R^2: -0.051 (0.201)
# MAE: 0.856 (0.084)
# MSE: 1.033 (0.208)

# %% [markdown]
# ### Pruebas de feature selection ###

# %%
m = LinearRegression()
m.fit(X,y)
evaluate(m, X, y)
# Out:
# {'MAE': 0.7841225423204529,
#  'MSE': 0.8738556867747462,
#  'R^2': 0.12903036644885524}

# %%
# https://scikit-learn.org/stable/modules/feature_selection.html

from sklearn.feature_selection import RFECV

m = RFECV(LinearRegression())
m.fit(X,y)
evaluate(m, X, y)
# Out:
# {'MAE': 0.7928021608434972,
#  'MSE': 0.882405796250938,
#  'R^2': 0.12050849512615891}

# %%
m.support_
# Out:
# array([ True,  True,  True,  True, False,  True,  True,  True,  True])

# %%
m.ranking_
# Out:
# array([1, 1, 1, 1, 2, 1, 1, 1, 1])

# %%
m.get_support(1)
# Out:
# array([0, 1, 2, 3, 5, 6, 7, 8], dtype=int64)

# %%
from sklearn.feature_selection import SelectFromModel

m = SelectFromModel(LinearRegression())
m.fit(X,y)
m.transform(X).shape
# Out:
# (130, 1)

# %%
evaluate(m.estimator_, X, y)
# Out:
# {'MAE': 0.7841225423204529,
#  'MSE': 0.8738556867747462,
#  'R^2': 0.12903036644885524}

# %%
m.get_support()
# Out:
# array([False, False,  True, False, False, False, False, False, False])

# %%
column_names = X_df.columns[m.get_support()]
column_names
# Out:
# Index(['avgSpeedPerTest'], dtype='object')
